# %%
'''import requests
from bs4 import BeautifulSoup
 
urls = 'https://raidforums.com/'
grab = requests.get(urls)
soup = BeautifulSoup(grab.text, 'html.parser')

 
# opening a file in write mode
#f = open("test1.txt", "w")
# traverse paragraphs from soup
links=[]
for link in soup.find_all("a",href=True):
    links.append(link.get('href'))
   #data = link.get('href')
   #f.write(data)
   #f.write("\n")
print(links) 
#f.close()'''
# Out:
# 'import requests\nfrom bs4 import BeautifulSoup\n \nurls = \'https://raidforums.com/\'\ngrab = requests.get(urls)\nsoup = BeautifulSoup(grab.text, \'html.parser\')\n\n \n# opening a file in write mode\n#f = open("test1.txt", "w")\n# traverse paragraphs from soup\nlinks=[]\nfor link in soup.find_all("a",href=True):\n    links.append(link.get(\'href\'))\n   #data = link.get(\'href\')\n   #f.write(data)\n   #f.write("\n")\nprint(links) \n#f.close()'

# %%
'''for lin in links:
    ur = lin
    gra = requests.get(ur)
    sop = BeautifulSoup(gra.text,'lxml')
    print(sop)'''
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <link href="https://raidforums.com" rel="canonical"/>
# <title>RaidForums</title>
# <meta content="website" property="og:type"/>
# <meta content="https://raidforums.com" property="og:url"/>
# <meta content="RaidForums" property="og:title"/>
# <meta content="RaidForums" property="og:site_name"/>
# <meta content="https://cdn.raidforums.com/i/RF_sSL0.png" property="og:image"/>
# <meta content="https://raidforums.com" name="identifier-url"/>
# <meta content="RaidForums" name="twitter:title"/>
# <meta content="RaidForums is a database sharing and marketplace forum. We have exclusive database breaches and leaks plus an active marketplace." name="description"/>
# <meta content="RaidForums is a database sharing and marketplace forum. We have exclusive database breaches and leaks plus an active marketplace." name="twitter:description"/>
# ...

# %%
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
import colorama

# %%
import time

# %%
internal_urls = set()
external_urls = set()

# %%
def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)

def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    # all URLs of `url`
    urls = set()
    # domain name of the URL without the protocol
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            # href empty tag
            continue   
        # join the URL if it's relative (not absolute link)
        href = urljoin(url, href)    
        parsed_href = urlparse(href)
        # remove URL GET parameters, URL fragments, etc.
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_valid(href):
            # not a valid URL
            continue
        if href in internal_urls:
            # already in the set
            continue
        if domain_name not in href:
            # external link
            if href not in external_urls:
                #print(f"{GRAY}[!] External link: {href}{RESET}")
                external_urls.add(href)
            continue
        #print(f"{GREEN}[*] Internal link: {href}{RESET}")
        urls.add(href)
        internal_urls.add(href)
        #print(internal_urls)

    return urls
# number of urls visited so far will be stored here
total_urls_visited = 0

'''def data_in_urls(internal_urls):
    for lin1 in internal_urls:
        grab1 = requests.get(lin1)
        soup1 = BeautifulSoup(grab1.text, 'html.parser')
        jobs=soup.find_all('td')
        for j in jobs:
            main_title=j.find('span')
    print(main_title.text)'''
            
        
        
                     

    

        
def crawl(url, max_urls=30):
    """
    Crawls a web page and extracts all links.
    You'll find all links in `external_urls` and `internal_urls` global set variables.
    params:
        max_urls (int): number of max urls to crawl, default is 30.
    """
    global total_urls_visited
    total_urls_visited += 1
    #print(f"{YELLOW}[*] Crawling: {url}{RESET}")
    links = get_all_website_links(url)
    for link in links:
        if total_urls_visited > max_urls:
            break
        crawl(link, max_urls=max_urls)
        
if __name__ == "__main__":    
    f = open('raidf.txt', 'w+')
    crawl("https://raidforums.com")
    #data_in_urls(internal_urls)
    #print("[+] Total Internal links:", len(internal_urls))
    #print("[+] Total External links:", len(external_urls))
    #print("[+] Total URLs:", len(external_urls) + len(internal_urls))

# %%
print(internal_urls)
# Out:
# {'https://raidforums.com/User-zizoze', 'https://raidforums.com/User-zex4', 'https://raidforums.com/User-kkikawy', 'https://raidforums.com/Thread-SELLING-Verify-accounts-crypto-com-Eu', 'https://raidforums.com/forum-197-page-4.html', 'https://raidforums.com/User-ramocode', 'https://raidforums.com/User-ptcoder', 'https://raidforums.com/User-mn0777', 'https://raidforums.com/User-YikesBoi16', 'https://raidforums.com/User-joeydalips', 'https://raidforums.com/User-SedNit', 'https://raidforums.com/User-EstelleOsborne', 'https://raidforums.com/User-veksi', 'https://raidforums.com/User-dhhmzz', 'https://raidforums.com/User-prondeau774', 'https://raidforums.com/User-mrmario', 'https://raidforums.com/User-deddodaddo', 'https://raidforums.com/User-djzballer', 'https://raidforums.com/User-yosafmohamad', 'https://raidforums.com/User-GrandTonyGuy', 'https://raidforums.com/User-Hello-world92', 'https://raidforums.com/User-kapitek', 'https://raidforums.com/User-WhiteHatME', 'https://raidforums.com/Th
# ...

# %%
with open('raidf.txt', 'w+')as ff:
    ff.write(str(internal_urls))

# %%
import ast
with open('raidf.txt', 'r+')as fff:
    ab=ast.literal_eval(fff.read())
    print(ab)
# Out:
# {'https://raidforums.com/User-zizoze', 'https://raidforums.com/User-zex4', 'https://raidforums.com/User-kkikawy', 'https://raidforums.com/Thread-SELLING-Verify-accounts-crypto-com-Eu', 'https://raidforums.com/forum-197-page-4.html', 'https://raidforums.com/User-ramocode', 'https://raidforums.com/User-ptcoder', 'https://raidforums.com/User-mn0777', 'https://raidforums.com/User-YikesBoi16', 'https://raidforums.com/User-joeydalips', 'https://raidforums.com/User-SedNit', 'https://raidforums.com/User-EstelleOsborne', 'https://raidforums.com/User-veksi', 'https://raidforums.com/User-dhhmzz', 'https://raidforums.com/User-prondeau774', 'https://raidforums.com/User-mrmario', 'https://raidforums.com/User-deddodaddo', 'https://raidforums.com/User-djzballer', 'https://raidforums.com/User-yosafmohamad', 'https://raidforums.com/User-GrandTonyGuy', 'https://raidforums.com/User-Hello-world92', 'https://raidforums.com/User-kapitek', 'https://raidforums.com/User-WhiteHatME', 'https://raidforums.com/Th
# ...

# %%
def data_in_urls(ur):
    for lin1 in ur:
        grab1 = requests.get(lin1).text
        soup1 = BeautifulSoup(grab1, 'lxml')
        try:
            jobs=soup1.find('td').text
            print(jobs)
        except:
            pass
        time.sleep(2)
        '''for j in jobs:
            main_title=j.find('a',class_="forums__forum-name").text
            print(main_title)
            #main_hea=soup1.find('a',class_='forums__forum-name').text
            all_tabledata = soup1.find('tb').text
            #print('main_heading: '+main_hea)
            print(lin1)
            print('all data:'+ all_tabledata)'''
    
data_in_urls(ab)

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %%
import requests
  
# Create a pool of proxies
proxies = {
    'http://212.237.26.124:8888',

}
  
url = 'https://raidforums.com/'
  
# Iterate the proxies and check if it is working.
for proxy in proxies:
    try:
  
        # https://ipecho.net/plain returns the ip address
        # of the current session if a GET request is sent.
        page = requests.get(
          url, proxies={"http": proxy, "https": proxy})
  
        # Prints Proxy server IP address if proxy is alive.
        print("Status OK, Output:", page.text)
  
    except OSError as e:
  
        # Proxy returns Connection error
        print(e)
# Out:
# HTTPSConnectionPool(host='raidforums.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DBEB9B7D00>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')))
# HTTPSConnectionPool(host='raidforums.com', port=443): Max retries exceeded with url: / (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001DBED49D670>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond')))
# ...

# %%
import requests
import random
from bs4 import BeautifulSoup as bs

def get_free_proxies():
    url3 = "https://free-proxy-list.net/"
    # get the HTTP response and construct soup object
    soup = bs(requests.get(url3).content, "html.parser")
    proxies1 = []
    for row in soup.find("table", attrs={"id": "proxylisttable"}).find_all("tr")[1:]:
        tds = row.find_all("td")
        try:
            ip = tds[0].text.strip()
            port = tds[1].text.strip()
            host = f"{ip}:{port}"
            proxies1.append(host)
        except IndexError:
            continue
    
    return proxies1
get_free_proxies()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d7c71101b664> in <module>
#      19
#      20     return proxies1
# ---> 21 get_free_proxies()
#
# <ipython-input-11-d7c71101b664> in get_free_proxies()
#       8     soup = bs(requests.get(url3).content, "html.parser")
#       9     proxies1 = []
# ---> 10     for row in soup.find("table", attrs={"id": "proxylisttable"}).find_all("tr")[1:]:
#      11         tds = row.find("td")
#      12         try:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
print(proxies1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-77ad67c22a2f> in <module>
# ----> 1 print(proxies1)
#
# NameError: name 'proxies1' is not defined

# %%
proxies2 = [
    '167.172.248.53:3128',
    '194.226.34.132:5555',
    '203.202.245.62:80',
    '141.0.70.211:8080',
    '118.69.50.155:80',
    '201.55.164.177:3128',
    '51.15.166.107:3128',
    '91.205.218.64:80',
    '128.199.237.57:8080',
]

# %%
def get_session(proxies2):
    # construct an HTTP session
    session = requests.Session()
    # choose one random proxy
    proxy = random.choice(proxies2)
    session.proxies2 = {"http": proxy, "https": proxy}
    return session

# %%
for i in range(10):
    s = get_session(proxies2)
    try:
        print("Request page with IP:", s.get("http://icanhazip.com", timeout=1.5).text.strip())
    except Exception as e:
        continue
# Out:
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199
# Request page with IP: 49.204.197.199

# %%
import requests
from bs4 import BeautifulSoup
import random
import concurrent.futures

#get the list of free proxies
def getProxies():
    r = requests.get('https://free-proxy-list.net/')
    soup = BeautifulSoup(r.content, 'html.parser')
    table = soup.find('tbody')
    proxies = []
    for row in table:
        if row.find_all('td')[4].text =='elite proxy':
            proxy = ':'.join([row.find_all('td')[0].text, row.find_all('td')[1].text])
            proxies.append(proxy)
        else:
            pass
    return proxies

def extract(proxy):
    #this was for when we took a list into the function, without conc futures.
    #proxy = random.choice(proxylist)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:80.0) Gecko/20100101 Firefox/80.0'}
    try:
        #change the url to https://httpbin.org/ip that doesnt block anything
        r = requests.get('https://httpbin.org/ip', headers=headers, proxies={'http' : proxy,'https': proxy}, timeout=1)
        print(r.json(), r.status_code)
    except:
        pass
    return proxy

proxylist = getProxies()
#print(len(proxylist))

#check them all with futures super quick
with concurrent.futures.ThreadPoolExecutor() as executor:
        executor.map(extract, proxylist)
# Out:
# {'origin': '36.95.65.99'} 200
# {'origin': '77.86.31.251'} 200
# {'origin': '207.135.203.241'} 200
# {'origin': '133.167.121.133'} 200
# {'origin': '149.19.224.36'} 200
# {'origin': '149.19.224.15'} 200
# {'origin': '133.167.77.163'} 200
# {'origin': '207.135.202.230'} 200
# {'origin': '3.10.246.23'} 200

# %%
prox = '34.138.225.120:8888'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:80.0) Gecko/20100101 Firefox/80.0'}
xy = requests.get('https://httpbin.org/ip',headers=headers,proxies={'http' : prox,'https': prox},timeout=1)
print(xy.status_code)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ...
